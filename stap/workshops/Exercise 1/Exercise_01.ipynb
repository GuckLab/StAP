# %% [markdown]
# # Welcome to the StAP Exercise 1 solutions
#
# **Topic: **
#
# - This notebook gives example solutions for "Exercise 1 -"
# - This notebook and the exercise pdf are hosted on the StAP repository on [github.com/GuckLab/StAP](https://github.com/GuckLab/StAP).
#
# Conrad Moeckel and Eoghan O'Connell, Guck Division, MPL, 2021

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 1

# %%
max(np.random.randint(1,6,2))
# Out:
# 5

# %%
res = []
n= 10**2

# %%
for i in range(1,n+1):
    res.append(max(np.random.randint(1,high=7,size = 2)))

# %%
(min(res),max(res),res.count(6))
# Out:
# (1, 6, 25)

# %%
hst= plt.hist(res,bins=[x-0.5 for x in list(range(1,8))],histtype='bar')

# %%
hst[0]/n
# Out:
# array([0.05, 0.11, 0.14, 0.22, 0.23, 0.25])

# %%
dlst = np.asarray([[1,1/36],[2,3/36],[3,5/36],[4,7/36],[5,9/36],[6,11/36]])

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(np.divide(hst[0]/n,dlst[:,1]))
ax.set_ylim([0.5,1.5])
ax.set_title('Sim/Theo')
1-np.mean(np.divide(hst[0]/n,dlst[:,1]))
# Out:
# -0.16626839826839834

# %% [markdown]
# ## Question 2

# %%
n=100
res = []
for i in range(1,n+1):
    res.append(np.sum(np.random.randint(1,high=7,size = 2)))

# %%
res.count(7)*500-100*(n-res.count(7))
# Out:
# 1400

# %%
def game1(n):
    res = []
    for j in range(0,n):
            res.append(np.sum(np.random.randint(1,high=7,size = 2)))
    return res.count(7)*500-100*(n-res.count(7))

# %%
game1(0)
# Out:
# 0

# %%
m= 100
res2 = np.zeros((100,m+1))
for j in range(0,100):
    for i in range(1,m):
        res2[j,i]= game1(j)

# %%
means = []
sds = []
for j in range (1,m-1):
    means.append(np.mean(res2[j,:]))
    sds.append(np.std(res2[j,:]))

# %%
nbm =  np.linspace(1,100,100)
theosd = 1/6*np.sqrt(5)*np.sqrt(500**2*nbm + 100**2*nbm)
theom = 0*nbm

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(means)
ax.plot(sds)
ax.plot(nbm,theosd,'r')
ax.plot(nbm,theom,'r')

# %%
def game2(val):
    return np.prod(np.random.randint(1,high=7,size = 2))-val

# %%
game2(10)
# Out:
# -7

# %%
m= 100;
res2 = np.zeros((100,m+1))
for j in range(0,100):
    for i in range(1,m):
        res2[j,i]= game2(10)

# %%
means = []
sds = []
for j in range (1,m-1):
    means.append(np.mean(res2[j,:]))
    sds.append(np.std(res2[j,:]))

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(means)
ax.plot(sds)
